# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split

# %%
urlA="https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Company.csv"

# %%
company=pd.read_csv(urlA)
company
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
plt.figure(figsize=(10,8))
plt.title('companyyyy')
sns.heatmap(company.corr(),annot=True , cmap="Blues")#va a creare una tabella con una palet di colori in base ai valori da un max a un min
# Out:
# <Axes: title={'center': 'companyyyy'}>

# %%
X=company.drop("Sales",axis=1)
y=company["Sales"]
X_train, X_test, y_train, y_test = train_test_split(X, y, 
test_size = 0.2, 
random_state = 667)
X_train.shape, X_test.shape
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.05498785,  0.10205335, -0.00059556])

# %%
model.intercept_
# Out:
# 4.645269208582116

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

r2score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('R2_score: ', r2score)
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
# Out:
# R2_score:  0.930613787380894
# MAE:  0.9703880894569759
# MSE:  1.986714176395249
# RMSE:  1.4095084875215362

# %%
model.predict([[1,2,3]])###prova se funziona
# Out:
# c:\Users\libero.bo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.90257708])

# %%
import joblib 
joblib.dump(model,'modello_company.pkl')
# Out:
# ['modello_company.pkl']

# %%
## to load model
newmodel = joblib.load('modello_company.pkl')
newmodel
# Out:
# LinearRegression()
